# %%
import numpy as np
import pandas as pd
#import seaborn as sns
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers, models
from tensorflow.keras.models import  Model
from sklearn.utils import resample
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
#from google.colab import drive
import time

np.random.seed(100)

# %%
train_dir = 'E:/dataset/FER2013+CK/train/'
val_dir = 'E:/dataset/FER2013/val/'

BS = 64
PATIENCE =10

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)
print(IMAGE_SHAPE)

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']
# Out:
# (48, 48, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
train_datagen = ImageDataGenerator(rescale = 1./255,
                                    zoom_range=0.3,
                                    shear_range=0.3,
                                    rotation_range=20,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    horizontal_flip=False
                                    
                                    )

val_datagen  = ImageDataGenerator(rescale = 1./255
                                   
                                  )

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)
#test_dir = 'N:/내 드라이브/DataSet/FER2013/test/'
val_dataset = val_datagen.flow_from_directory(directory = val_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 29611 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
from IPython.display import Image, HTML
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
val_count = count_exp(val_dir, 'val')

HTML(train_count.append(val_count).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>4040</td>
#       <td>495</td>
#       <td>4122</td>
#       <td>7284</td>
#       <td>5558</td>
#       <td>4858</td>
#       <td>3254</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>467</td>
#       <td>56</td>
#       <td>496</td>
#       <td>895</td>
#       <td>607</td>
#       <td>653</td>
#       <td>415</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = val_dataset.class_indices
class_labels
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
# # lot distribution of train/test dataste per class

x = list(val_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = val_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Val"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
from collections import Counter
counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  
class_weights
# Out:
# {0: 1.8, 1: 14.72, 2: 1.77, 3: 1.0, 4: 1.31, 5: 1.5, 6: 2.24}

# %%
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras.layers import Activation, BatchNormalization, Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop, Adam

base_model = tf.keras.applications.densenet.DenseNet121(input_shape=IMAGE_SHAPE, include_top=False, weights="imagenet")
base_model.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 54, 54, 3)   0           ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 24, 24, 64)   9408        ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 24, 24, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 24, 24, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 26, 26, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 12, 12, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 12, 12, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 12, 12, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 12, 12, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 12, 12, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 12, 12, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 12, 12, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 12, 12, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 12, 12, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 12, 12, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 12, 12, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 12, 12, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 12, 12, 128)  20480       ['conv2_block4_0_relu[0][0]']
#  conv2_block4_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 12, 12, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 12, 12, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 12, 12, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 12, 12, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 12, 12, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 12, 12, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 12, 12, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 12, 12, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 12, 12, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 12, 12, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 12, 12, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 12, 12, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 12, 12, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 6, 6, 128)    0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 6, 6, 128)   512         ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 6, 6, 128)    16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 6, 6, 160)   0           ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 6, 6, 160)   640         ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 6, 6, 160)   0           ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 6, 6, 128)    20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 6, 6, 192)   0           ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 6, 6, 192)   768         ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 6, 6, 192)   0           ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 6, 6, 128)    24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 6, 6, 224)   0           ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 6, 6, 224)   896         ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 6, 6, 224)   0           ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 6, 6, 128)    28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 6, 6, 256)   0           ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 6, 6, 256)   0           ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 6, 6, 128)    32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 6, 6, 288)   0           ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 6, 6, 288)   1152        ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 6, 6, 288)   0           ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 6, 6, 128)    36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block6_1_bn[0][0]']
#  n)
#  conv3_block6_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 6, 6, 320)   0           ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 6, 6, 320)   1280        ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 6, 6, 320)   0           ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 6, 6, 128)    40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 6, 6, 352)   0           ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 6, 6, 352)   1408        ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 6, 6, 352)   0           ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 6, 6, 128)    45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 6, 6, 384)   0           ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 6, 6, 384)   1536        ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 6, 6, 384)   0           ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 6, 6, 128)    49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 6, 6, 32)     36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 6, 6, 416)   0           ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 6, 6, 416)   1664        ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 6, 6, 416)   0           ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 6, 6, 128)    53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 6, 6, 128)   512         ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 6, 6, 128)   0           ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 6, 6, 32)     36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 6, 6, 448)   0           ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 6, 6, 448)   1792        ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 6, 6, 448)   0           ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 6, 6, 128)    57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 6, 6, 128)   512         ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 6, 6, 128)   0           ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 6, 6, 32)     36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 6, 6, 480)   0           ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 6, 6, 480)   1920        ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 6, 6, 480)   0           ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 6, 6, 128)    61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 6, 6, 128)   512         ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 6, 6, 128)   0           ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 6, 6, 32)     36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 6, 6, 512)   0           ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 6, 6, 512)    2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 6, 6, 512)    0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 6, 6, 256)    131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 3, 3, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 3, 3, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 3, 3, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 3, 3, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 3, 3, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 3, 3, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 3, 3, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 3, 3, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 3, 3, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 3, 3, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 3, 3, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 3, 3, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 3, 3, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 3, 3, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 3, 3, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 3, 3, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 3, 3, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 3, 3, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 3, 3, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 3, 3, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 3, 3, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 3, 3, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 3, 3, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 3, 3, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 3, 3, 128)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 3, 3, 32)     36864       ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_concat (Concatena  (None, 3, 3, 448)   0           ['conv4_block5_concat[0][0]',
# ...
#
#  conv5_block8_concat (Concatena  (None, 1, 1, 768)   0           ['conv5_block7_concat[0][0]',
#  te)                                                              'conv5_block8_2_conv[0][0]']
#
#  conv5_block9_0_bn (BatchNormal  (None, 1, 1, 768)   3072        ['conv5_block8_concat[0][0]']
#  ization)
#
#  conv5_block9_0_relu (Activatio  (None, 1, 1, 768)   0           ['conv5_block9_0_bn[0][0]']
#  n)
#
#  conv5_block9_1_conv (Conv2D)   (None, 1, 1, 128)    98304       ['conv5_block9_0_relu[0][0]']
#
#  conv5_block9_1_bn (BatchNormal  (None, 1, 1, 128)   512         ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 1, 1, 128)   0           ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 1, 1, 32)     36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 1, 1, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 1, 1, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 1, 1, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 1, 1, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 1, 1, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 1, 1, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 1, 1, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 1, 1, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 1, 1, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 1, 1, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 1, 1, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 1, 1, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 1, 1, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 1, 1, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 1, 1, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 1, 1, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#  conv5_block13_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 1, 1, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 1, 1, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 1, 1, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 1, 1, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 1, 1, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 1, 1, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 1, 1, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 1, 1, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 1, 1, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 1, 1, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 1, 1, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 1, 1, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 1, 1, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 1, 1, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 1, 1, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 1, 1, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 1, 1, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 1, 1, 1024)   0           ['bn[0][0]']
#
# ==================================================================================================
# Total params: 7,037,504
# Trainable params: 6,953,856
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable=True

# %%
model = models.Sequential()
model.add(base_model)
#model.add(layers.Conv2D(1280, (1, 1), (1, 1), 'same', activation='relu'))
#model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
#model.add(BatchNormalization())
#model.add(Dropout(0.3))
#model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 1, 1, 1024)        7037504
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 7,301,703
# Trainable params: 7,218,055
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  callbacks = [early_stopping, checkpoint]
  return callbacks

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score
]

model.compile(
    optimizer=Adam(learning_rate=0.00001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']#, f1_score]
     #metrics=METRICS        
)

# %%
with tf.device('/GPU:0'):
    history = model.fit(train_dataset, validation_data=val_dataset,  
                      callbacks=callbackFunction('new_4-2_D'),
                      batch_size=BS,  
                      epochs = 30, 
                      verbose=1,
                      class_weight = class_weights
                      )
# Out:
# Epoch 1/30
# 463/463 [==============================] - ETA: 0s - loss: 4.2547 - accuracy: 0.1635
# Epoch 1: val_accuracy improved from -inf to 0.18390, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 118s 234ms/step - loss: 4.2547 - accuracy: 0.1635 - val_loss: 2.1415 - val_accuracy: 0.1839
# Epoch 2/30
# 463/463 [==============================] - ETA: 0s - loss: 3.7768 - accuracy: 0.1707
# Epoch 2: val_accuracy improved from 0.18390 to 0.20730, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 40s 87ms/step - loss: 3.7768 - accuracy: 0.1707 - val_loss: 2.0014 - val_accuracy: 0.2073
# Epoch 3/30
# 463/463 [==============================] - ETA: 0s - loss: 3.5402 - accuracy: 0.1875
# Epoch 3: val_accuracy improved from 0.20730 to 0.23600, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 40s 85ms/step - loss: 3.5402 - accuracy: 0.1875 - val_loss: 1.9206 - val_accuracy: 0.2360
# Epoch 4/30
# 463/463 [==============================] - ETA: 0s - loss: 3.4039 - accuracy: 0.1981
# Epoch 4: val_accuracy improved from 0.23600 to 0.24742, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 85ms/step - loss: 3.4039 - accuracy: 0.1981 - val_loss: 1.8699 - val_accuracy: 0.2474
# Epoch 5/30
# 463/463 [==============================] - ETA: 0s - loss: 3.3081 - accuracy: 0.2117
# Epoch 5: val_accuracy improved from 0.24742 to 0.27417, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 40s 86ms/step - loss: 3.3081 - accuracy: 0.2117 - val_loss: 1.8211 - val_accuracy: 0.2742
# Epoch 6/30
# 463/463 [==============================] - ETA: 0s - loss: 3.2240 - accuracy: 0.2290
# Epoch 6: val_accuracy improved from 0.27417 to 0.29005, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 3.2240 - accuracy: 0.2290 - val_loss: 1.7815 - val_accuracy: 0.2901
# Epoch 7/30
# 463/463 [==============================] - ETA: 0s - loss: 3.1678 - accuracy: 0.2487
# Epoch 7: val_accuracy improved from 0.29005 to 0.31123, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 83ms/step - loss: 3.1678 - accuracy: 0.2487 - val_loss: 1.7514 - val_accuracy: 0.3112
# Epoch 8/30
# 463/463 [==============================] - ETA: 0s - loss: 3.0941 - accuracy: 0.2619
# Epoch 8: val_accuracy improved from 0.31123 to 0.34717, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 38s 83ms/step - loss: 3.0941 - accuracy: 0.2619 - val_loss: 1.6986 - val_accuracy: 0.3472
# Epoch 9/30
# 463/463 [==============================] - ETA: 0s - loss: 3.0480 - accuracy: 0.2802
# Epoch 9: val_accuracy improved from 0.34717 to 0.35024, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 83ms/step - loss: 3.0480 - accuracy: 0.2802 - val_loss: 1.6800 - val_accuracy: 0.3502
# Epoch 10/30
# 463/463 [==============================] - ETA: 0s - loss: 2.9667 - accuracy: 0.2991
# Epoch 10: val_accuracy improved from 0.35024 to 0.36110, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 38s 83ms/step - loss: 2.9667 - accuracy: 0.2991 - val_loss: 1.6492 - val_accuracy: 0.3611
# Epoch 11/30
# 463/463 [==============================] - ETA: 0s - loss: 2.9177 - accuracy: 0.3134
# Epoch 11: val_accuracy improved from 0.36110 to 0.37253, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 83ms/step - loss: 2.9177 - accuracy: 0.3134 - val_loss: 1.6090 - val_accuracy: 0.3725
# Epoch 12/30
# 463/463 [==============================] - ETA: 0s - loss: 2.8661 - accuracy: 0.3273
# Epoch 12: val_accuracy improved from 0.37253 to 0.38897, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 38s 83ms/step - loss: 2.8661 - accuracy: 0.3273 - val_loss: 1.5813 - val_accuracy: 0.3890
# Epoch 13/30
# 463/463 [==============================] - ETA: 0s - loss: 2.8211 - accuracy: 0.3439
# Epoch 13: val_accuracy improved from 0.38897 to 0.39983, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.8211 - accuracy: 0.3439 - val_loss: 1.5607 - val_accuracy: 0.3998
# Epoch 14/30
# 463/463 [==============================] - ETA: 0s - loss: 2.7736 - accuracy: 0.3594
# Epoch 14: val_accuracy improved from 0.39983 to 0.40457, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.7736 - accuracy: 0.3594 - val_loss: 1.5532 - val_accuracy: 0.4046
# Epoch 15/30
# 463/463 [==============================] - ETA: 0s - loss: 2.7069 - accuracy: 0.3750
# Epoch 15: val_accuracy improved from 0.40457 to 0.40958, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 85ms/step - loss: 2.7069 - accuracy: 0.3750 - val_loss: 1.5354 - val_accuracy: 0.4096
# Epoch 16/30
# 463/463 [==============================] - ETA: 0s - loss: 2.6826 - accuracy: 0.3750
# Epoch 16: val_accuracy improved from 0.40958 to 0.41989, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 40s 86ms/step - loss: 2.6826 - accuracy: 0.3750 - val_loss: 1.5049 - val_accuracy: 0.4199
# Epoch 17/30
# 463/463 [==============================] - ETA: 0s - loss: 2.6363 - accuracy: 0.3914
# Epoch 17: val_accuracy improved from 0.41989 to 0.43048, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 85ms/step - loss: 2.6363 - accuracy: 0.3914 - val_loss: 1.4845 - val_accuracy: 0.4305
# Epoch 18/30
# 463/463 [==============================] - ETA: 0s - loss: 2.5929 - accuracy: 0.4035
# Epoch 18: val_accuracy did not improve from 0.43048
# 463/463 [==============================] - 39s 84ms/step - loss: 2.5929 - accuracy: 0.4035 - val_loss: 1.4652 - val_accuracy: 0.4305
# Epoch 19/30
# 463/463 [==============================] - ETA: 0s - loss: 2.5800 - accuracy: 0.4014
# Epoch 19: val_accuracy improved from 0.43048 to 0.44553, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 85ms/step - loss: 2.5800 - accuracy: 0.4014 - val_loss: 1.4421 - val_accuracy: 0.4455
# Epoch 20/30
# 463/463 [==============================] - ETA: 0s - loss: 2.5071 - accuracy: 0.4205
# Epoch 20: val_accuracy did not improve from 0.44553
# 463/463 [==============================] - 39s 83ms/step - loss: 2.5071 - accuracy: 0.4205 - val_loss: 1.4303 - val_accuracy: 0.4444
# Epoch 21/30
# 463/463 [==============================] - ETA: 0s - loss: 2.4814 - accuracy: 0.4270
# Epoch 21: val_accuracy improved from 0.44553 to 0.44664, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 85ms/step - loss: 2.4814 - accuracy: 0.4270 - val_loss: 1.4340 - val_accuracy: 0.4466
# Epoch 22/30
# 463/463 [==============================] - ETA: 0s - loss: 2.4606 - accuracy: 0.4284
# Epoch 22: val_accuracy improved from 0.44664 to 0.45417, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 85ms/step - loss: 2.4606 - accuracy: 0.4284 - val_loss: 1.3949 - val_accuracy: 0.4542
# Epoch 23/30
# 463/463 [==============================] - ETA: 0s - loss: 2.4089 - accuracy: 0.4433
# Epoch 23: val_accuracy improved from 0.45417 to 0.46977, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.4089 - accuracy: 0.4433 - val_loss: 1.3796 - val_accuracy: 0.4698
# Epoch 24/30
# 463/463 [==============================] - ETA: 0s - loss: 2.4093 - accuracy: 0.4488
# Epoch 24: val_accuracy improved from 0.46977 to 0.47311, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.4093 - accuracy: 0.4488 - val_loss: 1.3617 - val_accuracy: 0.4731
# Epoch 25/30
# 463/463 [==============================] - ETA: 0s - loss: 2.3678 - accuracy: 0.4537
# Epoch 25: val_accuracy improved from 0.47311 to 0.47646, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.3678 - accuracy: 0.4537 - val_loss: 1.3546 - val_accuracy: 0.4765
# Epoch 26/30
# 463/463 [==============================] - ETA: 0s - loss: 2.3301 - accuracy: 0.4643
# Epoch 26: val_accuracy improved from 0.47646 to 0.48091, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.3301 - accuracy: 0.4643 - val_loss: 1.3379 - val_accuracy: 0.4809
# Epoch 27/30
# 463/463 [==============================] - ETA: 0s - loss: 2.3235 - accuracy: 0.4694
# Epoch 27: val_accuracy improved from 0.48091 to 0.48370, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.3235 - accuracy: 0.4694 - val_loss: 1.3435 - val_accuracy: 0.4837
# Epoch 28/30
# 463/463 [==============================] - ETA: 0s - loss: 2.2908 - accuracy: 0.4708
# Epoch 28: val_accuracy improved from 0.48370 to 0.49819, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 39s 84ms/step - loss: 2.2908 - accuracy: 0.4708 - val_loss: 1.3022 - val_accuracy: 0.4982
# Epoch 29/30
# 463/463 [==============================] - ETA: 0s - loss: 2.2665 - accuracy: 0.4780
# Epoch 29: val_accuracy did not improve from 0.49819
# 463/463 [==============================] - 39s 84ms/step - loss: 2.2665 - accuracy: 0.4780 - val_loss: 1.3124 - val_accuracy: 0.4940
# Epoch 30/30
# 463/463 [==============================] - ETA: 0s - loss: 2.2418 - accuracy: 0.4799
# Epoch 30: val_accuracy improved from 0.49819 to 0.50878, saving model to Checkpoints\new_4-2_D.h5
# 463/463 [==============================] - 40s 87ms/step - loss: 2.2418 - accuracy: 0.4799 - val_loss: 1.2983 - val_accuracy: 0.5088

# %%
import matplotlib.pyplot as plt

# Extract training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Plot training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('new_4-1_D_FER2013.h5')

# %%
test_dir = 'E:/dataset/Only_Kor_Test/'
test_datagen  = ImageDataGenerator(rescale = 1./255)
test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
jaffe_dir = 'E:/dataset/jaffedbase/'
jaffe_datagen  = ImageDataGenerator(rescale = 1./255)
jaffe_dataset = test_datagen.flow_from_directory(directory = jaffe_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 758 images belonging to 7 classes.
# Found 213 images belonging to 7 classes.

# %%
train_evalation = model.evaluate(train_dataset)
val_evalation = model.evaluate(val_dataset)
test_evaluation = model.evaluate(test_dataset)
jaffe_evaluation = model.evaluate(jaffe_dataset)
# Out:
# 463/463 [==============================] - 16s 35ms/step - loss: 1.3087 - accuracy: 0.5044
# 57/57 [==============================] - 1s 24ms/step - loss: 1.2983 - accuracy: 0.5088
# 12/12 [==============================] - 1s 90ms/step - loss: 2.1721 - accuracy: 0.2573
# 4/4 [==============================] - 1s 261ms/step - loss: 1.9644 - accuracy: 0.3005

# %%
metric_list = ["Loss","Accuracy", "Precision", "F1_Score", "Recall", "Auc"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in val_evalation],
                           [round(num, 3) for num in test_evaluation],
                           [round(num, 3) for num in jaffe_evaluation],
                          )),
                  columns=['Metric Name', 'Train', 'Validate', 'KFE', 'JAFFE'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#       <th>KFE</th>
#       <th>JAFFE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>1.309</td>
#       <td>1.298</td>
#       <td>2.172</td>
#       <td>1.964</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.504</td>
#       <td>0.509</td>
#       <td>0.257</td>
#       <td>0.300</td>
#     </tr>
#   </tbody>
# </table>
