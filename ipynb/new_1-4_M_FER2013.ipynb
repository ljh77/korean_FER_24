# %%
import numpy as np
import pandas as pd
#import seaborn as sns
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers, models
from tensorflow.keras.models import  Model
from sklearn.utils import resample
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
#from google.colab import drive
import time

np.random.seed(100)

# %%
train_dir = 'E:/dataset/CK_PIC/'
val_dir = 'E:/dataset/FER2013/val/'

BS = 10
PATIENCE =10

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)
print(IMAGE_SHAPE)

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']
# Out:
# (48, 48, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
train_datagen = ImageDataGenerator(rescale = 1./255,
                                    zoom_range=0.3,
                                    shear_range=0.3,
                                    rotation_range=20,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    horizontal_flip=False
                                    
                                    )

val_datagen  = ImageDataGenerator(rescale = 1./255
                                   
                                  )

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)
#test_dir = 'N:/내 드라이브/DataSet/FER2013/test/'
val_dataset = val_datagen.flow_from_directory(directory = val_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 902 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
from IPython.display import Image, HTML
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
val_count = count_exp(val_dir, 'val')

HTML(train_count.append(val_count).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>45</td>
#       <td>59</td>
#       <td>25</td>
#       <td>69</td>
#       <td>593</td>
#       <td>28</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>467</td>
#       <td>56</td>
#       <td>496</td>
#       <td>895</td>
#       <td>607</td>
#       <td>653</td>
#       <td>415</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = val_dataset.class_indices
class_labels
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
# # lot distribution of train/test dataste per class

x = list(val_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = val_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Val"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
from collections import Counter
counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  
class_weights
# Out:
# {0: 13.18, 1: 10.05, 2: 23.72, 3: 8.59, 4: 1.0, 5: 21.18, 6: 7.14}

# %%
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras.layers import Activation, BatchNormalization, Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop, Adam

base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(input_shape=IMAGE_SHAPE, include_top=False, weights="imagenet")
base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  Conv1 (Conv2D)                 (None, 24, 24, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 24, 24, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 24, 24, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 24, 24, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 24, 24, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 24, 24, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 24, 24, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 24, 24, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 24, 24, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 24, 24, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 24, 24, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 25, 25, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 12, 12, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 12, 12, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 12, 12, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 12, 12, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 12, 12, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 12, 12, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 12, 12, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 12, 12, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 12, 12, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 12, 12, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 12, 12, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 12, 12, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 12, 12, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 12, 12, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 13, 13, 144)  0           ['block_3_expand_relu[0][0]']
#  block_3_depthwise (DepthwiseCo  (None, 6, 6, 144)   1296        ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 6, 6, 144)   576         ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 6, 6, 144)    0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 6, 6, 32)     4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 6, 6, 32)    128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 6, 6, 192)    6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 6, 6, 192)   768         ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 6, 6, 192)    0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 6, 6, 192)   1728        ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 6, 6, 192)   768         ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 6, 6, 192)    0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 6, 6, 32)     6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 6, 6, 32)    128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 6, 6, 32)     0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 6, 6, 192)    6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 6, 6, 192)   768         ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 6, 6, 192)    0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 6, 6, 192)   1728        ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 6, 6, 192)   768         ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 6, 6, 192)    0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 6, 6, 32)     6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 6, 6, 32)    128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 6, 6, 32)     0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 6, 6, 192)    6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 6, 6, 192)   768         ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 6, 6, 192)    0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 7, 7, 192)    0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 3, 3, 192)   1728        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 3, 3, 192)   768         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 3, 3, 192)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 3, 3, 64)     12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 3, 3, 64)    256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 3, 3, 384)    24576       ['block_6_project_BN[0][0]']
#  block_7_expand_BN (BatchNormal  (None, 3, 3, 384)   1536        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 3, 3, 384)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 3, 3, 384)   3456        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 3, 3, 384)   1536        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 3, 3, 384)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 3, 3, 64)     24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 3, 3, 64)    256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 3, 3, 64)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 3, 3, 384)    24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 3, 3, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 3, 3, 384)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 3, 3, 384)   3456        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 3, 3, 384)   1536        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 3, 3, 384)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 3, 3, 64)     24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 3, 3, 64)    256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 3, 3, 64)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 3, 3, 384)    24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 3, 3, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 3, 3, 384)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 3, 3, 384)   3456        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 3, 3, 384)   1536        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 3, 3, 384)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 3, 3, 64)     24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 3, 3, 64)    256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 3, 3, 64)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 3, 3, 384)    24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 3, 3, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 3, 3, 384)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 3, 3, 384)   3456        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 3, 3, 384)   1536        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 3, 3, 384)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 3, 3, 96)     36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 3, 3, 96)    384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 3, 3, 576)    55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 3, 3, 576)   2304        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 3, 3, 576)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 3, 3, 576)   5184        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 3, 3, 576)   2304        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 3, 3, 576)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 3, 3, 96)     55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 3, 3, 96)    384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 3, 3, 96)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 3, 3, 576)    55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 3, 3, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 3, 3, 576)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 3, 3, 576)   5184        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 3, 3, 576)   2304        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 3, 3, 576)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 3, 3, 96)     55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 3, 3, 96)    384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 3, 3, 96)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 3, 3, 576)    55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 3, 3, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 3, 3, 576)    0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 5, 5, 576)    0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 2, 2, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 2, 2, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 2, 2, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 2, 2, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 2, 2, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 2, 2, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 2, 2, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 2, 2, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 2, 2, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 2, 2, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 2, 2, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 2, 2, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 2, 2, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 2, 2, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 2, 2, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 2, 2, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 2, 2, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 2, 2, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 2, 2, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 2, 2, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 2, 2, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 2, 2, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 2, 2, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 2, 2, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 2, 2, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 2, 2, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 2, 2, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 2, 2, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 2, 2, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 2, 2, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 2, 2, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 2, 2, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 2, 2, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 2, 2, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable=True

# %%
model = models.Sequential()
model.add(base_model)
#model.add(layers.Conv2D(1280, (1, 1), (1, 1), 'same', activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
#model.add(BatchNormalization())
#model.add(Dropout(0.3))
#model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 2, 2, 1280)       2257984
#  ional)
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 1280)       0
#  )
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 2,587,719
# Trainable params: 2,553,607
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  callbacks = [early_stopping, checkpoint]
  return callbacks

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score
]

model.compile(
    optimizer=Adam(learning_rate=0.00001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']#, f1_score]
     #metrics=METRICS        
)

# %%
with tf.device('/GPU:0'):
    history = model.fit(train_dataset, validation_data=val_dataset,  
                      callbacks=callbackFunction('1-4_M_FER2013'),
                      batch_size=BS,  
                      #steps_per_epoch=499,
                      epochs = 30, 
                      verbose=1,
                      class_weight = class_weights
                      
                      )
# Out:
# Epoch 1/30
# 91/91 [==============================] - ETA: 0s - loss: 13.2869 - accuracy: 0.1973
# Epoch 1: val_accuracy improved from -inf to 0.11145, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 6s 64ms/step - loss: 13.2869 - accuracy: 0.1973 - val_loss: 2.1614 - val_accuracy: 0.1115
# Epoch 2/30
# 90/91 [============================>.] - ETA: 0s - loss: 13.7832 - accuracy: 0.2063
# Epoch 2: val_accuracy improved from 0.11145 to 0.11452, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 57ms/step - loss: 13.8155 - accuracy: 0.2062 - val_loss: 2.1443 - val_accuracy: 0.1145
# Epoch 3/30
# 90/91 [============================>.] - ETA: 0s - loss: 12.7385 - accuracy: 0.2063
# Epoch 3: val_accuracy improved from 0.11452 to 0.11480, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 58ms/step - loss: 12.6316 - accuracy: 0.2073 - val_loss: 2.1343 - val_accuracy: 0.1148
# Epoch 4/30
# 91/91 [==============================] - ETA: 0s - loss: 12.3200 - accuracy: 0.2151
# Epoch 4: val_accuracy did not improve from 0.11480
# 91/91 [==============================] - 5s 55ms/step - loss: 12.3200 - accuracy: 0.2151 - val_loss: 2.1596 - val_accuracy: 0.1103
# Epoch 5/30
# 90/91 [============================>.] - ETA: 0s - loss: 12.7027 - accuracy: 0.1984
# Epoch 5: val_accuracy did not improve from 0.11480
# 91/91 [==============================] - 5s 57ms/step - loss: 12.6327 - accuracy: 0.2007 - val_loss: 2.1793 - val_accuracy: 0.1128
# Epoch 6/30
# 89/91 [============================>.] - ETA: 0s - loss: 12.6561 - accuracy: 0.1950
# Epoch 6: val_accuracy improved from 0.11480 to 0.12371, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 58ms/step - loss: 12.9122 - accuracy: 0.1951 - val_loss: 2.1762 - val_accuracy: 0.1237
# Epoch 7/30
# 91/91 [==============================] - ETA: 0s - loss: 12.6515 - accuracy: 0.1962
# Epoch 7: val_accuracy improved from 0.12371 to 0.12483, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 59ms/step - loss: 12.6515 - accuracy: 0.1962 - val_loss: 2.1863 - val_accuracy: 0.1248
# Epoch 8/30
# 89/91 [============================>.] - ETA: 0s - loss: 11.7520 - accuracy: 0.2120
# Epoch 8: val_accuracy did not improve from 0.12483
# 91/91 [==============================] - 5s 55ms/step - loss: 11.9604 - accuracy: 0.2151 - val_loss: 2.2068 - val_accuracy: 0.1179
# Epoch 9/30
# 91/91 [==============================] - ETA: 0s - loss: 11.9324 - accuracy: 0.1973
# Epoch 9: val_accuracy did not improve from 0.12483
# 91/91 [==============================] - 5s 55ms/step - loss: 11.9324 - accuracy: 0.1973 - val_loss: 2.2148 - val_accuracy: 0.1232
# Epoch 10/30
# 91/91 [==============================] - ETA: 0s - loss: 11.7351 - accuracy: 0.1929
# Epoch 10: val_accuracy did not improve from 0.12483
# 91/91 [==============================] - 5s 56ms/step - loss: 11.7351 - accuracy: 0.1929 - val_loss: 2.2379 - val_accuracy: 0.1226
# Epoch 11/30
# 91/91 [==============================] - ETA: 0s - loss: 11.6527 - accuracy: 0.2184
# Epoch 11: val_accuracy improved from 0.12483 to 0.13096, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 59ms/step - loss: 11.6527 - accuracy: 0.2184 - val_loss: 2.2427 - val_accuracy: 0.1310
# Epoch 12/30
# 90/91 [============================>.] - ETA: 0s - loss: 11.4842 - accuracy: 0.2197
# Epoch 12: val_accuracy improved from 0.13096 to 0.13374, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 57ms/step - loss: 11.4260 - accuracy: 0.2228 - val_loss: 2.2410 - val_accuracy: 0.1337
# Epoch 13/30
# 90/91 [============================>.] - ETA: 0s - loss: 11.9802 - accuracy: 0.2029
# Epoch 13: val_accuracy improved from 0.13374 to 0.13709, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 59ms/step - loss: 11.9218 - accuracy: 0.2040 - val_loss: 2.2431 - val_accuracy: 0.1371
# Epoch 14/30
# 89/91 [============================>.] - ETA: 0s - loss: 11.5302 - accuracy: 0.1950
# Epoch 14: val_accuracy improved from 0.13709 to 0.13959, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 59ms/step - loss: 11.4662 - accuracy: 0.1940 - val_loss: 2.2398 - val_accuracy: 0.1396
# Epoch 15/30
# 89/91 [============================>.] - ETA: 0s - loss: 11.0886 - accuracy: 0.2313
# Epoch 15: val_accuracy did not improve from 0.13959
# 91/91 [==============================] - 5s 56ms/step - loss: 11.0602 - accuracy: 0.2295 - val_loss: 2.2395 - val_accuracy: 0.1390
# Epoch 16/30
# 90/91 [============================>.] - ETA: 0s - loss: 11.4206 - accuracy: 0.1827
# Epoch 16: val_accuracy did not improve from 0.13959
# 91/91 [==============================] - 5s 56ms/step - loss: 11.3719 - accuracy: 0.1818 - val_loss: 2.2348 - val_accuracy: 0.1382
# Epoch 17/30
# 91/91 [==============================] - ETA: 0s - loss: 10.6725 - accuracy: 0.2350
# Epoch 17: val_accuracy did not improve from 0.13959
# 91/91 [==============================] - 5s 56ms/step - loss: 10.6725 - accuracy: 0.2350 - val_loss: 2.2451 - val_accuracy: 0.1365
# Epoch 18/30
# 89/91 [============================>.] - ETA: 0s - loss: 10.7118 - accuracy: 0.2041
# Epoch 18: val_accuracy improved from 0.13959 to 0.14099, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 58ms/step - loss: 10.8497 - accuracy: 0.2051 - val_loss: 2.2565 - val_accuracy: 0.1410
# Epoch 19/30
# 91/91 [==============================] - ETA: 0s - loss: 11.2080 - accuracy: 0.2184
# Epoch 19: val_accuracy did not improve from 0.14099
# 91/91 [==============================] - 5s 56ms/step - loss: 11.2080 - accuracy: 0.2184 - val_loss: 2.2708 - val_accuracy: 0.1354
# Epoch 20/30
# 89/91 [============================>.] - ETA: 0s - loss: 11.0891 - accuracy: 0.2041
# Epoch 20: val_accuracy improved from 0.14099 to 0.14349, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 59ms/step - loss: 11.1188 - accuracy: 0.2051 - val_loss: 2.2605 - val_accuracy: 0.1435
# Epoch 21/30
# 91/91 [==============================] - ETA: 0s - loss: 11.0540 - accuracy: 0.2228
# Epoch 21: val_accuracy did not improve from 0.14349
# 91/91 [==============================] - 5s 57ms/step - loss: 11.0540 - accuracy: 0.2228 - val_loss: 2.2663 - val_accuracy: 0.1365
# Epoch 22/30
# 91/91 [==============================] - ETA: 0s - loss: 9.9241 - accuracy: 0.2395
# Epoch 22: val_accuracy improved from 0.14349 to 0.14489, saving model to Checkpoints\1-4_M_FER2013.h5
# 91/91 [==============================] - 5s 58ms/step - loss: 9.9241 - accuracy: 0.2395 - val_loss: 2.2718 - val_accuracy: 0.1449
# Epoch 23/30
# 91/91 [==============================] - ETA: 0s - loss: 10.8115 - accuracy: 0.2251
# Epoch 23: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 57ms/step - loss: 10.8115 - accuracy: 0.2251 - val_loss: 2.2664 - val_accuracy: 0.1407
# Epoch 24/30
# 91/91 [==============================] - ETA: 0s - loss: 9.4851 - accuracy: 0.2506
# Epoch 24: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 57ms/step - loss: 9.4851 - accuracy: 0.2506 - val_loss: 2.2595 - val_accuracy: 0.1413
# Epoch 25/30
# 91/91 [==============================] - ETA: 0s - loss: 9.8171 - accuracy: 0.2228
# Epoch 25: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 56ms/step - loss: 9.8171 - accuracy: 0.2228 - val_loss: 2.2580 - val_accuracy: 0.1385
# Epoch 26/30
# 91/91 [==============================] - ETA: 0s - loss: 10.5860 - accuracy: 0.2073
# Epoch 26: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 56ms/step - loss: 10.5860 - accuracy: 0.2073 - val_loss: 2.2746 - val_accuracy: 0.1413
# Epoch 27/30
# 89/91 [============================>.] - ETA: 0s - loss: 10.4603 - accuracy: 0.2392
# Epoch 27: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 56ms/step - loss: 10.4224 - accuracy: 0.2395 - val_loss: 2.2847 - val_accuracy: 0.1388
# Epoch 28/30
# 90/91 [============================>.] - ETA: 0s - loss: 10.5881 - accuracy: 0.2164
# Epoch 28: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 56ms/step - loss: 10.6550 - accuracy: 0.2162 - val_loss: 2.2907 - val_accuracy: 0.1376
# Epoch 29/30
# 89/91 [============================>.] - ETA: 0s - loss: 9.7139 - accuracy: 0.2460
# Epoch 29: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 55ms/step - loss: 9.8648 - accuracy: 0.2450 - val_loss: 2.2858 - val_accuracy: 0.1407
# Epoch 30/30
# 89/91 [============================>.] - ETA: 0s - loss: 10.4820 - accuracy: 0.2336
# Epoch 30: val_accuracy did not improve from 0.14489
# 91/91 [==============================] - 5s 55ms/step - loss: 10.3521 - accuracy: 0.2328 - val_loss: 2.2939 - val_accuracy: 0.1346

# %%
import matplotlib.pyplot as plt

# Extract training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Plot training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('new_1-4_M_FER2013_2.h5')

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
val_evaluation = model.evaluate(val_dataset)
#test_evaluation2 = model.evaluate(test_dataset2)
# Out:
# 91/91 [==============================] - 1s 9ms/step - loss: 2.2096 - accuracy: 0.1652
# 359/359 [==============================] - 3s 8ms/step - loss: 2.2939 - accuracy: 0.1346

# %%
metric_list = ["Loss","Accuracy", "Precision", "F1_Score", "Recall", "Auc"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in val_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>2.210</td>
#       <td>2.294</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.165</td>
#       <td>0.135</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_dir = 'E:/dataset/Only_Kor_Test/'
test_datagen  = ImageDataGenerator(rescale = 1./255)
test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
jaffe_dir = 'E:/dataset/jaffedbase/'
jaffe_datagen  = ImageDataGenerator(rescale = 1./255)
jaffe_dataset = test_datagen.flow_from_directory(directory = jaffe_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 758 images belonging to 7 classes.
# Found 213 images belonging to 7 classes.

# %%
test_evaluation = model.evaluate(test_dataset)
jaffe_evaluation = model.evaluate(jaffe_dataset)
# Out:
# 76/76 [==============================] - 1s 14ms/step - loss: 2.2833 - accuracy: 0.1464
# 22/22 [==============================] - 0s 17ms/step - loss: 2.1696 - accuracy: 0.1690

# %%
metric_list = ["Loss","Accuracy", "Precision", "F1_Score", "Recall", "Auc"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in val_evaluation],
                           [round(num, 3) for num in test_evaluation],
                           [round(num, 3) for num in jaffe_evaluation],
                          )),
                  columns=['Metric Name', 'Train', 'Validate', 'KFE', 'JAFFE'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#       <th>KFE</th>
#       <th>JAFFE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>2.210</td>
#       <td>2.294</td>
#       <td>2.283</td>
#       <td>2.170</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.165</td>
#       <td>0.135</td>
#       <td>0.146</td>
#       <td>0.169</td>
#     </tr>
#   </tbody>
# </table>
