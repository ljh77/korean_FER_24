# %%
import numpy as np
import pandas as pd
#import seaborn as sns
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers, models
from tensorflow.keras.models import  Model
from sklearn.utils import resample
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
#from google.colab import drive
import time

np.random.seed(100)

# %%
train_dir = 'E:/dataset/FER2013+CK+KFE/train/'
val_dir = 'E:/dataset/FER2013/val/'

BS = 64
PATIENCE =10

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)
print(IMAGE_SHAPE)

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']
# Out:
# (48, 48, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
train_datagen = ImageDataGenerator(rescale = 1./255,
                                    zoom_range=0.3,
                                    shear_range=0.3,
                                    rotation_range=20,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    horizontal_flip=False
                                    
                                    )

val_datagen  = ImageDataGenerator(rescale = 1./255
                                   
                                  )

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)
#test_dir = 'N:/내 드라이브/DataSet/FER2013/test/'
val_dataset = val_datagen.flow_from_directory(directory = val_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 31935 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
from IPython.display import Image, HTML
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
val_count = count_exp(val_dir, 'val')

HTML(train_count.append(val_count).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>4376</td>
#       <td>796</td>
#       <td>4416</td>
#       <td>7634</td>
#       <td>5936</td>
#       <td>5201</td>
#       <td>3576</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>467</td>
#       <td>56</td>
#       <td>496</td>
#       <td>895</td>
#       <td>607</td>
#       <td>653</td>
#       <td>415</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = val_dataset.class_indices
class_labels
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
# # lot distribution of train/test dataste per class

x = list(val_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = val_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Val"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
from collections import Counter
counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  
class_weights
# Out:
# {0: 1.74, 1: 9.59, 2: 1.73, 3: 1.0, 4: 1.29, 5: 1.47, 6: 2.13}

# %%
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras.layers import Activation, BatchNormalization, Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop, Adam

base_model = tf.keras.applications.vgg16.VGG16(input_shape=IMAGE_SHAPE, include_top=False, weights="imagenet")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable=True

# %%
model = models.Sequential()
model.add(base_model)
#model.add(layers.Conv2D(1280, (1, 1), (1, 1), 'same', activation='relu'))
#model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
#model.add(BatchNormalization())
#model.add(Dropout(0.3))
#model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 14,847,815
# Trainable params: 14,847,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  callbacks = [early_stopping, checkpoint]
  return callbacks

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score
]

model.compile(
    optimizer=Adam(learning_rate=0.00001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']#, f1_score]
     #metrics=METRICS        
)

# %%
with tf.device('/GPU:0'):
    history = model.fit(train_dataset, validation_data=val_dataset,  
                      callbacks=callbackFunction('3-3_V16'),
                      batch_size=BS,  
                      epochs = 30, 
                      verbose=1,
                      class_weight = class_weights
                      )
# Out:
# Epoch 1/30
# 499/499 [==============================] - ETA: 0s - loss: 3.1213 - accuracy: 0.2408
# Epoch 1: val_accuracy improved from -inf to 0.38339, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 133s 257ms/step - loss: 3.1213 - accuracy: 0.2408 - val_loss: 1.6364 - val_accuracy: 0.3834
# Epoch 2/30
# 499/499 [==============================] - ETA: 0s - loss: 2.8094 - accuracy: 0.3483
# Epoch 2: val_accuracy improved from 0.38339 to 0.45723, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 2.8094 - accuracy: 0.3483 - val_loss: 1.4511 - val_accuracy: 0.4572
# Epoch 3/30
# 499/499 [==============================] - ETA: 0s - loss: 2.6072 - accuracy: 0.4044
# Epoch 3: val_accuracy improved from 0.45723 to 0.48565, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 61ms/step - loss: 2.6072 - accuracy: 0.4044 - val_loss: 1.3464 - val_accuracy: 0.4857
# Epoch 4/30
# 499/499 [==============================] - ETA: 0s - loss: 2.4750 - accuracy: 0.4366
# Epoch 4: val_accuracy did not improve from 0.48565
# 499/499 [==============================] - 31s 62ms/step - loss: 2.4750 - accuracy: 0.4366 - val_loss: 1.3685 - val_accuracy: 0.4787
# Epoch 5/30
# 499/499 [==============================] - ETA: 0s - loss: 2.3945 - accuracy: 0.4544
# Epoch 5: val_accuracy improved from 0.48565 to 0.50655, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 2.3945 - accuracy: 0.4544 - val_loss: 1.2880 - val_accuracy: 0.5065
# Epoch 6/30
# 499/499 [==============================] - ETA: 0s - loss: 2.3144 - accuracy: 0.4708
# Epoch 6: val_accuracy improved from 0.50655 to 0.52410, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 2.3144 - accuracy: 0.4708 - val_loss: 1.2631 - val_accuracy: 0.5241
# Epoch 7/30
# 499/499 [==============================] - ETA: 0s - loss: 2.2400 - accuracy: 0.4920
# Epoch 7: val_accuracy improved from 0.52410 to 0.53859, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 2.2400 - accuracy: 0.4920 - val_loss: 1.2129 - val_accuracy: 0.5386
# Epoch 8/30
# 499/499 [==============================] - ETA: 0s - loss: 2.1924 - accuracy: 0.5002
# Epoch 8: val_accuracy improved from 0.53859 to 0.56450, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 2.1924 - accuracy: 0.5002 - val_loss: 1.1519 - val_accuracy: 0.5645
# Epoch 9/30
# 499/499 [==============================] - ETA: 0s - loss: 2.1440 - accuracy: 0.5106
# Epoch 9: val_accuracy did not improve from 0.56450
# 499/499 [==============================] - 31s 62ms/step - loss: 2.1440 - accuracy: 0.5106 - val_loss: 1.1903 - val_accuracy: 0.5503
# Epoch 10/30
# 499/499 [==============================] - ETA: 0s - loss: 2.1080 - accuracy: 0.5170
# Epoch 10: val_accuracy improved from 0.56450 to 0.56812, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 2.1080 - accuracy: 0.5170 - val_loss: 1.1525 - val_accuracy: 0.5681
# Epoch 11/30
# 499/499 [==============================] - ETA: 0s - loss: 2.0635 - accuracy: 0.5273
# Epoch 11: val_accuracy improved from 0.56812 to 0.56952, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 2.0635 - accuracy: 0.5273 - val_loss: 1.1462 - val_accuracy: 0.5695
# Epoch 12/30
# 499/499 [==============================] - ETA: 0s - loss: 2.0139 - accuracy: 0.5380
# Epoch 12: val_accuracy improved from 0.56952 to 0.57871, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 2.0139 - accuracy: 0.5380 - val_loss: 1.1368 - val_accuracy: 0.5787
# Epoch 13/30
# 499/499 [==============================] - ETA: 0s - loss: 1.9923 - accuracy: 0.5445
# Epoch 13: val_accuracy improved from 0.57871 to 0.58651, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 1.9923 - accuracy: 0.5445 - val_loss: 1.1132 - val_accuracy: 0.5865
# Epoch 14/30
# 499/499 [==============================] - ETA: 0s - loss: 1.9528 - accuracy: 0.5526
# Epoch 14: val_accuracy did not improve from 0.58651
# 499/499 [==============================] - 31s 62ms/step - loss: 1.9528 - accuracy: 0.5526 - val_loss: 1.1203 - val_accuracy: 0.5846
# Epoch 15/30
# 499/499 [==============================] - ETA: 0s - loss: 1.9308 - accuracy: 0.5578
# Epoch 15: val_accuracy did not improve from 0.58651
# 499/499 [==============================] - 31s 62ms/step - loss: 1.9308 - accuracy: 0.5578 - val_loss: 1.1382 - val_accuracy: 0.5759
# Epoch 16/30
# 499/499 [==============================] - ETA: 0s - loss: 1.9030 - accuracy: 0.5640
# Epoch 16: val_accuracy did not improve from 0.58651
# 499/499 [==============================] - 31s 62ms/step - loss: 1.9030 - accuracy: 0.5640 - val_loss: 1.1214 - val_accuracy: 0.5823
# Epoch 17/30
# 499/499 [==============================] - ETA: 0s - loss: 1.8611 - accuracy: 0.5718
# Epoch 17: val_accuracy improved from 0.58651 to 0.58763, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 1.8611 - accuracy: 0.5718 - val_loss: 1.1346 - val_accuracy: 0.5876
# Epoch 18/30
# 499/499 [==============================] - ETA: 0s - loss: 1.8409 - accuracy: 0.5747
# Epoch 18: val_accuracy improved from 0.58763 to 0.59682, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 1.8409 - accuracy: 0.5747 - val_loss: 1.0772 - val_accuracy: 0.5968
# Epoch 19/30
# 499/499 [==============================] - ETA: 0s - loss: 1.8202 - accuracy: 0.5807
# Epoch 19: val_accuracy improved from 0.59682 to 0.60602, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 1.8202 - accuracy: 0.5807 - val_loss: 1.0685 - val_accuracy: 0.6060
# Epoch 20/30
# 499/499 [==============================] - ETA: 0s - loss: 1.7886 - accuracy: 0.5869
# Epoch 20: val_accuracy improved from 0.60602 to 0.60936, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 1.7886 - accuracy: 0.5869 - val_loss: 1.0484 - val_accuracy: 0.6094
# Epoch 21/30
# 499/499 [==============================] - ETA: 0s - loss: 1.7675 - accuracy: 0.5906
# Epoch 21: val_accuracy improved from 0.60936 to 0.61103, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 1.7675 - accuracy: 0.5906 - val_loss: 1.0468 - val_accuracy: 0.6110
# Epoch 22/30
# 499/499 [==============================] - ETA: 0s - loss: 1.7436 - accuracy: 0.5942
# Epoch 22: val_accuracy did not improve from 0.61103
# 499/499 [==============================] - 31s 62ms/step - loss: 1.7436 - accuracy: 0.5942 - val_loss: 1.0603 - val_accuracy: 0.6021
# Epoch 23/30
# 499/499 [==============================] - ETA: 0s - loss: 1.7450 - accuracy: 0.5938
# Epoch 23: val_accuracy improved from 0.61103 to 0.61549, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 1.7450 - accuracy: 0.5938 - val_loss: 1.0487 - val_accuracy: 0.6155
# Epoch 24/30
# 499/499 [==============================] - ETA: 0s - loss: 1.6931 - accuracy: 0.6050
# Epoch 24: val_accuracy improved from 0.61549 to 0.62134, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 1.6931 - accuracy: 0.6050 - val_loss: 1.0459 - val_accuracy: 0.6213
# Epoch 25/30
# 499/499 [==============================] - ETA: 0s - loss: 1.6744 - accuracy: 0.6105
# Epoch 25: val_accuracy did not improve from 0.62134
# 499/499 [==============================] - 31s 62ms/step - loss: 1.6744 - accuracy: 0.6105 - val_loss: 1.0603 - val_accuracy: 0.6099
# Epoch 26/30
# 499/499 [==============================] - ETA: 0s - loss: 1.6597 - accuracy: 0.6163
# Epoch 26: val_accuracy improved from 0.62134 to 0.63165, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 63ms/step - loss: 1.6597 - accuracy: 0.6163 - val_loss: 1.0151 - val_accuracy: 0.6317
# Epoch 27/30
# 499/499 [==============================] - ETA: 0s - loss: 1.6444 - accuracy: 0.6166
# Epoch 27: val_accuracy did not improve from 0.63165
# 499/499 [==============================] - 31s 62ms/step - loss: 1.6444 - accuracy: 0.6166 - val_loss: 1.0159 - val_accuracy: 0.6311
# Epoch 28/30
# 499/499 [==============================] - ETA: 0s - loss: 1.6132 - accuracy: 0.6239
# Epoch 28: val_accuracy improved from 0.63165 to 0.63332, saving model to Checkpoints\3-3_V16.h5
# 499/499 [==============================] - 31s 62ms/step - loss: 1.6132 - accuracy: 0.6239 - val_loss: 1.0208 - val_accuracy: 0.6333
# Epoch 29/30
# 499/499 [==============================] - ETA: 0s - loss: 1.6031 - accuracy: 0.6240
# Epoch 29: val_accuracy did not improve from 0.63332
# 499/499 [==============================] - 31s 62ms/step - loss: 1.6031 - accuracy: 0.6240 - val_loss: 1.0286 - val_accuracy: 0.6294
# Epoch 30/30
# 499/499 [==============================] - ETA: 0s - loss: 1.5924 - accuracy: 0.6288
# Epoch 30: val_accuracy did not improve from 0.63332
# 499/499 [==============================] - 31s 62ms/step - loss: 1.5924 - accuracy: 0.6288 - val_loss: 1.0264 - val_accuracy: 0.6264

# %%
import matplotlib.pyplot as plt

# Extract training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Plot training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('new_3-1_v16_FER2013.h5')

# %%
test_dir = 'E:/dataset/Only_Kor_Test/'
test_datagen  = ImageDataGenerator(rescale = 1./255)
test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
jaffe_dir = 'E:/dataset/jaffedbase/'
jaffe_datagen  = ImageDataGenerator(rescale = 1./255)
jaffe_dataset = test_datagen.flow_from_directory(directory = jaffe_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 758 images belonging to 7 classes.
# Found 213 images belonging to 7 classes.

# %%
train_evalation = model.evaluate(train_dataset)
val_evalation = model.evaluate(val_dataset)
test_evaluation = model.evaluate(test_dataset)
jaffe_evaluation = model.evaluate(jaffe_dataset)
# Out:
# 499/499 [==============================] - 30s 60ms/step - loss: 0.9456 - accuracy: 0.6456
# 57/57 [==============================] - 1s 21ms/step - loss: 1.0264 - accuracy: 0.6264
# 12/12 [==============================] - 2s 199ms/step - loss: 1.9720 - accuracy: 0.3140
# 4/4 [==============================] - 1s 207ms/step - loss: 2.0485 - accuracy: 0.3239

# %%
metric_list = ["Loss","Accuracy", "Precision", "F1_Score", "Recall", "Auc"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in val_evalation],
                           [round(num, 3) for num in test_evaluation],
                           [round(num, 3) for num in jaffe_evaluation],
                          )),
                  columns=['Metric Name', 'Train', 'Validate', 'KFE', 'JAFFE'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#       <th>KFE</th>
#       <th>JAFFE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.946</td>
#       <td>1.026</td>
#       <td>1.972</td>
#       <td>2.049</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.646</td>
#       <td>0.626</td>
#       <td>0.314</td>
#       <td>0.324</td>
#     </tr>
#   </tbody>
# </table>
