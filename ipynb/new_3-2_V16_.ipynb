# %%
import numpy as np
import pandas as pd
#import seaborn as sns
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras import layers, models
from tensorflow.keras.models import  Model
from sklearn.utils import resample
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
#from google.colab import drive
import time

np.random.seed(100)

# %%
train_dir = 'E:/dataset/FER2013+CK/train/'
val_dir = 'E:/dataset/FER2013/val/'

BS = 64
PATIENCE =10

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)
print(IMAGE_SHAPE)

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']
# Out:
# (48, 48, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
train_datagen = ImageDataGenerator(rescale = 1./255,
                                    zoom_range=0.3,
                                    shear_range=0.3,
                                    rotation_range=20,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    horizontal_flip=False
                                    
                                    )

val_datagen  = ImageDataGenerator(rescale = 1./255
                                   
                                  )

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)
#test_dir = 'N:/내 드라이브/DataSet/FER2013/test/'
val_dataset = val_datagen.flow_from_directory(directory = val_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 29611 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.

# %%
from IPython.display import Image, HTML
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
val_count = count_exp(val_dir, 'val')

HTML(train_count.append(val_count).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Angry</th>
#       <th>Disgust</th>
#       <th>Fear</th>
#       <th>Happy</th>
#       <th>Neutral</th>
#       <th>Sad</th>
#       <th>Surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>4040</td>
#       <td>495</td>
#       <td>4122</td>
#       <td>7284</td>
#       <td>5558</td>
#       <td>4858</td>
#       <td>3254</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>467</td>
#       <td>56</td>
#       <td>496</td>
#       <td>895</td>
#       <td>607</td>
#       <td>653</td>
#       <td>415</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = val_dataset.class_indices
class_labels
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
# # lot distribution of train/test dataste per class

x = list(val_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = val_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Val"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
from collections import Counter
counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  
class_weights
# Out:
# {0: 1.8, 1: 14.72, 2: 1.77, 3: 1.0, 4: 1.31, 5: 1.5, 6: 2.24}

# %%
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras.layers import Activation, BatchNormalization, Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop, Adam

base_model = tf.keras.applications.vgg16.VGG16(input_shape=IMAGE_SHAPE, include_top=False, weights="imagenet")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable=True

# %%
model = models.Sequential()
model.add(base_model)
#model.add(layers.Conv2D(1280, (1, 1), (1, 1), 'same', activation='relu'))
#model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
#model.add(BatchNormalization())
#model.add(Dropout(0.3))
#model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 14,847,815
# Trainable params: 14,847,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import keras.backend as K

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  callbacks = [early_stopping, checkpoint]
  return callbacks

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score
]

model.compile(
    optimizer=Adam(learning_rate=0.00001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']#, f1_score]
     #metrics=METRICS        
)

# %%
with tf.device('/GPU:0'):
    history = model.fit(train_dataset, validation_data=val_dataset,  
                      callbacks=callbackFunction('3-2_V16'),
                      batch_size=BS,  
                      epochs = 30, 
                      verbose=1,
                      class_weight = class_weights
                      )
# Out:
# Epoch 1/30
# 463/463 [==============================] - ETA: 0s - loss: 3.2605 - accuracy: 0.2167
# Epoch 1: val_accuracy improved from -inf to 0.36612, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 113s 233ms/step - loss: 3.2605 - accuracy: 0.2167 - val_loss: 1.7160 - val_accuracy: 0.3661
# Epoch 2/30
# 462/463 [============================>.] - ETA: 0s - loss: 2.9332 - accuracy: 0.3400
# Epoch 2: val_accuracy improved from 0.36612 to 0.45389, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 17s 37ms/step - loss: 2.9339 - accuracy: 0.3401 - val_loss: 1.4436 - val_accuracy: 0.4539
# Epoch 3/30
# 462/463 [============================>.] - ETA: 0s - loss: 2.6972 - accuracy: 0.4011
# Epoch 3: val_accuracy improved from 0.45389 to 0.45723, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 16s 34ms/step - loss: 2.6961 - accuracy: 0.4012 - val_loss: 1.3793 - val_accuracy: 0.4572
# Epoch 4/30
# 463/463 [==============================] - ETA: 0s - loss: 2.5077 - accuracy: 0.4398
# Epoch 4: val_accuracy improved from 0.45723 to 0.50014, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 16s 35ms/step - loss: 2.5077 - accuracy: 0.4398 - val_loss: 1.3158 - val_accuracy: 0.5001
# Epoch 5/30
# 463/463 [==============================] - ETA: 0s - loss: 2.4123 - accuracy: 0.4622
# Epoch 5: val_accuracy improved from 0.50014 to 0.50571, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 16s 35ms/step - loss: 2.4123 - accuracy: 0.4622 - val_loss: 1.3064 - val_accuracy: 0.5057
# Epoch 6/30
# 463/463 [==============================] - ETA: 0s - loss: 2.3219 - accuracy: 0.4815
# Epoch 6: val_accuracy improved from 0.50571 to 0.52967, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 16s 34ms/step - loss: 2.3219 - accuracy: 0.4815 - val_loss: 1.2439 - val_accuracy: 0.5297
# Epoch 7/30
# 462/463 [============================>.] - ETA: 0s - loss: 2.2586 - accuracy: 0.4963
# Epoch 7: val_accuracy improved from 0.52967 to 0.54277, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 19s 41ms/step - loss: 2.2578 - accuracy: 0.4964 - val_loss: 1.2196 - val_accuracy: 0.5428
# Epoch 8/30
# 462/463 [============================>.] - ETA: 0s - loss: 2.1900 - accuracy: 0.5107
# Epoch 8: val_accuracy improved from 0.54277 to 0.54639, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 16s 35ms/step - loss: 2.1913 - accuracy: 0.5107 - val_loss: 1.1958 - val_accuracy: 0.5464
# Epoch 9/30
# 462/463 [============================>.] - ETA: 0s - loss: 2.1332 - accuracy: 0.5189
# Epoch 9: val_accuracy improved from 0.54639 to 0.55224, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 21s 45ms/step - loss: 2.1330 - accuracy: 0.5189 - val_loss: 1.1730 - val_accuracy: 0.5522
# Epoch 10/30
# 463/463 [==============================] - ETA: 0s - loss: 2.1004 - accuracy: 0.5306
# Epoch 10: val_accuracy did not improve from 0.55224
# 463/463 [==============================] - 19s 41ms/step - loss: 2.1004 - accuracy: 0.5306 - val_loss: 1.2110 - val_accuracy: 0.5469
# Epoch 11/30
# 463/463 [==============================] - ETA: 0s - loss: 2.0439 - accuracy: 0.5385
# Epoch 11: val_accuracy improved from 0.55224 to 0.55949, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 20s 43ms/step - loss: 2.0439 - accuracy: 0.5385 - val_loss: 1.1658 - val_accuracy: 0.5595
# Epoch 12/30
# 463/463 [==============================] - ETA: 0s - loss: 2.0052 - accuracy: 0.5456
# Epoch 12: val_accuracy improved from 0.55949 to 0.57230, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 16s 35ms/step - loss: 2.0052 - accuracy: 0.5456 - val_loss: 1.1449 - val_accuracy: 0.5723
# Epoch 13/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.9618 - accuracy: 0.5589
# Epoch 13: val_accuracy did not improve from 0.57230
# 463/463 [==============================] - 16s 34ms/step - loss: 1.9618 - accuracy: 0.5590 - val_loss: 1.2004 - val_accuracy: 0.5511
# Epoch 14/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.9514 - accuracy: 0.5575
# Epoch 14: val_accuracy improved from 0.57230 to 0.57760, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 19s 41ms/step - loss: 1.9512 - accuracy: 0.5574 - val_loss: 1.1173 - val_accuracy: 0.5776
# Epoch 15/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.8963 - accuracy: 0.5652
# Epoch 15: val_accuracy improved from 0.57760 to 0.58178, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 21s 45ms/step - loss: 1.8964 - accuracy: 0.5653 - val_loss: 1.1065 - val_accuracy: 0.5818
# Epoch 16/30
# 463/463 [==============================] - ETA: 0s - loss: 1.8650 - accuracy: 0.5752
# Epoch 16: val_accuracy improved from 0.58178 to 0.59209, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 19s 41ms/step - loss: 1.8650 - accuracy: 0.5752 - val_loss: 1.0844 - val_accuracy: 0.5921
# Epoch 17/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.8497 - accuracy: 0.5804
# Epoch 17: val_accuracy did not improve from 0.59209
# 463/463 [==============================] - 19s 42ms/step - loss: 1.8493 - accuracy: 0.5805 - val_loss: 1.1028 - val_accuracy: 0.5876
# Epoch 18/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.8076 - accuracy: 0.5862
# Epoch 18: val_accuracy did not improve from 0.59209
# 463/463 [==============================] - 19s 41ms/step - loss: 1.8078 - accuracy: 0.5861 - val_loss: 1.1302 - val_accuracy: 0.5754
# Epoch 19/30
# 463/463 [==============================] - ETA: 0s - loss: 1.7859 - accuracy: 0.5914
# Epoch 19: val_accuracy improved from 0.59209 to 0.59515, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 19s 41ms/step - loss: 1.7859 - accuracy: 0.5914 - val_loss: 1.0988 - val_accuracy: 0.5952
# Epoch 20/30
# 463/463 [==============================] - ETA: 0s - loss: 1.7604 - accuracy: 0.5961
# Epoch 20: val_accuracy improved from 0.59515 to 0.60351, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 19s 41ms/step - loss: 1.7604 - accuracy: 0.5961 - val_loss: 1.0737 - val_accuracy: 0.6035
# Epoch 21/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.7333 - accuracy: 0.6035
# Epoch 21: val_accuracy improved from 0.60351 to 0.60658, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 19s 41ms/step - loss: 1.7341 - accuracy: 0.6034 - val_loss: 1.0679 - val_accuracy: 0.6066
# Epoch 22/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.7336 - accuracy: 0.6051
# Epoch 22: val_accuracy did not improve from 0.60658
# 463/463 [==============================] - 19s 41ms/step - loss: 1.7335 - accuracy: 0.6052 - val_loss: 1.0771 - val_accuracy: 0.5946
# Epoch 23/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.6885 - accuracy: 0.6097
# Epoch 23: val_accuracy improved from 0.60658 to 0.61048, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 21s 46ms/step - loss: 1.6887 - accuracy: 0.6097 - val_loss: 1.0746 - val_accuracy: 0.6105
# Epoch 24/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.6656 - accuracy: 0.6157
# Epoch 24: val_accuracy did not improve from 0.61048
# 463/463 [==============================] - 19s 42ms/step - loss: 1.6648 - accuracy: 0.6159 - val_loss: 1.0640 - val_accuracy: 0.6063
# Epoch 25/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.6440 - accuracy: 0.6167
# Epoch 25: val_accuracy did not improve from 0.61048
# 463/463 [==============================] - 19s 42ms/step - loss: 1.6429 - accuracy: 0.6169 - val_loss: 1.0637 - val_accuracy: 0.6060
# Epoch 26/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.6292 - accuracy: 0.6204
# Epoch 26: val_accuracy improved from 0.61048 to 0.61410, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 20s 43ms/step - loss: 1.6292 - accuracy: 0.6204 - val_loss: 1.0413 - val_accuracy: 0.6141
# Epoch 27/30
# 463/463 [==============================] - ETA: 0s - loss: 1.6005 - accuracy: 0.6293
# Epoch 27: val_accuracy improved from 0.61410 to 0.61967, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 20s 42ms/step - loss: 1.6005 - accuracy: 0.6293 - val_loss: 1.0364 - val_accuracy: 0.6197
# Epoch 28/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.5705 - accuracy: 0.6336
# Epoch 28: val_accuracy did not improve from 0.61967
# 463/463 [==============================] - 19s 42ms/step - loss: 1.5706 - accuracy: 0.6336 - val_loss: 1.0374 - val_accuracy: 0.6121
# Epoch 29/30
# 463/463 [==============================] - ETA: 0s - loss: 1.5618 - accuracy: 0.6391
# Epoch 29: val_accuracy improved from 0.61967 to 0.62357, saving model to Checkpoints\3-2_V16.h5
# 463/463 [==============================] - 20s 44ms/step - loss: 1.5618 - accuracy: 0.6391 - val_loss: 1.0071 - val_accuracy: 0.6236
# Epoch 30/30
# 462/463 [============================>.] - ETA: 0s - loss: 1.5502 - accuracy: 0.6381
# Epoch 30: val_accuracy did not improve from 0.62357
# 463/463 [==============================] - 18s 39ms/step - loss: 1.5500 - accuracy: 0.6380 - val_loss: 1.0172 - val_accuracy: 0.6205

# %%
import matplotlib.pyplot as plt

# Extract training history
training_loss = history.history['loss']
training_accuracy = history.history['accuracy']
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']

# Plot training and validation loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('new_3-1_v16_FER2013.h5')

# %%
test_dir = 'E:/dataset/Only_Kor_Test/'
test_datagen  = ImageDataGenerator(rescale = 1./255)
test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
jaffe_dir = 'E:/dataset/jaffedbase/'
jaffe_datagen  = ImageDataGenerator(rescale = 1./255)
jaffe_dataset = test_datagen.flow_from_directory(directory = jaffe_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  #shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 758 images belonging to 7 classes.
# Found 213 images belonging to 7 classes.

# %%
train_evalation = model.evaluate(train_dataset)
val_evalation = model.evaluate(val_dataset)
test_evaluation = model.evaluate(test_dataset)
jaffe_evaluation = model.evaluate(jaffe_dataset)
# Out:
# 463/463 [==============================] - 15s 32ms/step - loss: 0.9214 - accuracy: 0.6561
# 57/57 [==============================] - 1s 12ms/step - loss: 1.0172 - accuracy: 0.6205
# 12/12 [==============================] - 1s 60ms/step - loss: 2.7335 - accuracy: 0.2361
# 4/4 [==============================] - 0s 93ms/step - loss: 2.2295 - accuracy: 0.2770

# %%
metric_list = ["Loss","Accuracy", "Precision", "F1_Score", "Recall", "Auc"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in val_evalation],
                           [round(num, 3) for num in test_evaluation],
                           [round(num, 3) for num in jaffe_evaluation],
                          )),
                  columns=['Metric Name', 'Train', 'Validate', 'KFE', 'JAFFE'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#       <th>KFE</th>
#       <th>JAFFE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.921</td>
#       <td>1.017</td>
#       <td>2.734</td>
#       <td>2.229</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.656</td>
#       <td>0.621</td>
#       <td>0.236</td>
#       <td>0.277</td>
#     </tr>
#   </tbody>
# </table>
